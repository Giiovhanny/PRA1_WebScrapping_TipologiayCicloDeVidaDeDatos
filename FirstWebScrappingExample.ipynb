# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import requests
import re
import whois

# %%
PATH=r"C:\Users\gio-v\Documents\UOC\Tipologiayciclodevidadelosdatos\chromedriver.exe"
webPage='https://www.youtube.com/c/KikeJav/videos'
#webPage='https://coinmarketcap.com/'
#webPage= 'https://www.binance.com/es'
driver = webdriver.Chrome(PATH)
driver.get(webPage)
print(driver.title)
#driver.find_element_by_class_name('button-group').click()
#driver.find_element_by_id('cmc-link').click()
#inputElement = driver.find_element_by_id("username")
#inputElement.send_keys('giiovhanny1')
#inputElement.send_keys(Keys.RETURN)
#driver.close()
def obt_robot(siteurl):
    if siteurl.endswith('/'):
        path=siteurl
    else:
        path=siteurl+'/'
    req=requests.get(path+'robots.txt',data=None)
    return req.text

#text = obt_robot(webPage)
#data = re.sub( r'<[^>]*>', ' ', text).strip()

#print(data)

#whois.whois(webPage)


SCROLL_PAUSE_TIME = 0.5
# Out:
# Kike Jav - YouTube

# %%
# Get scroll height
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

# %%
html = driver.find_element_by_tag_name('html')
html.send_keys(Keys.END)

# %%
 driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

# %%
# Out:
# User-agent: *
# Allow: /

# %%
#print(text)
# Out:
# <!DOCTYPE html>
# <html lang="es">
# <head>
#     <meta http-equiv="X-UA-Compatible" content="IE=7,8,9,10" />
#     <meta http-equiv="Content-Type" content="text/html; charset=utf-8" />
#     <meta charset="utf-8" />
#     <meta name="apple-itunes-app" content="app-id=880551607">
#     <meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1" />
#     <title>Banco del Pacifico - Http404</title>
#     <link href="/pacificon.ico" rel="shortcut icon" type="image/x-icon" />
#     <link href="/Content/css/cssintermaticonaos?v=SOtSqxZ2YZYMUw0UB7uFXp14zcV9gpHY3K567NREgUY1" rel="stylesheet"/>
#
#     <link href="/Content/impromptu/impromptucss?v=Kiab0-q5AicqpWBzC-UvM8nkLMawYYgAodVG7dhucbA1" rel="stylesheet"/>
#
#     <script src="/bundles/jquery?v=XrScCT693DyOnAZpu4pIgv826ntWeUmBY7iOgMbP9B41"></script>
#
#     <script src="/bundles/impromptujs?v=i5co50cQs0zMrKnmyk_Pj6ftXbqd7fTwH7uz2Xq6Ooo1"></script>
#
# ...

# %%
# Out:
# {'domain_name': ['COINMARKETCAP.COM', 'coinmarketcap.com'],
#  'registrar': 'MarkMonitor, Inc.',
#  'whois_server': 'whois.markmonitor.com',
#  'referral_url': None,
#  'updated_date': [datetime.datetime(2020, 6, 23, 17, 16, 57),
#   datetime.datetime(2020, 6, 23, 10, 26, 31)],
#  'creation_date': [datetime.datetime(2013, 4, 28, 17, 30, 25),
#   datetime.datetime(2013, 4, 28, 10, 30, 25)],
#  'expiration_date': [datetime.datetime(2025, 4, 28, 17, 30, 25),
#   datetime.datetime(2025, 4, 28, 10, 30, 25)],
#  'name_servers': ['KARA.NS.CLOUDFLARE.COM',
#   'PHIL.NS.CLOUDFLARE.COM',
#   'phil.ns.cloudflare.com',
#   'kara.ns.cloudflare.com'],
#  'status': ['clientDeleteProhibited https://icann.org/epp#clientDeleteProhibited',
#   'clientTransferProhibited https://icann.org/epp#clientTransferProhibited',
#   'clientUpdateProhibited https://icann.org/epp#clientUpdateProhibited',
#   'serverDeleteProhibited https://icann.org/epp#serverDeleteProhibited',
# ...
